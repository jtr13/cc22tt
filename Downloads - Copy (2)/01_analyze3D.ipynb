# %% [markdown]
# # CAMERA Workshop 2019
#
# Daniela Ushizima, Alexandre de Siqueira, Stéfan van der Walt
#
# _BIDS @ University of California, Berkeley_
#
# _Lawrence Berkeley National Laboratory - LBNL_
#
# * Support material for the tutorial _Image processing for microCT using scikit-image (Part II)_.
#
# This tutorial will introduce how to analyze three dimensional stacked and volumetric
# images in Python, mainly using scikit-image. Here we will learn how to:
#   * pre-process data using filtering, binarization and segmentation techniques.
#   * inspect, count and measure attributes of objects and regions of interest in the data.
#   * visualize 3D data.
#
# Please prepare for the tutorial by [installing the pre-requisite software](preparation.md) beforehand.
#
# For more info:
#   * [[CAMERA Workshop 2019]](http://microct.lbl.gov/cameratomo2019/)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from skimage import io

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive/data images videos/MicroCT_synthetic/synthetic/"
# Out:
# bead_pack  benchmark_synthetic_microCT	castle	gambier  lrc32

# %%
input_filename="/content/drive/My Drive/data images videos/MicroCT_synthetic/bead_pack_artifacts_small.tif"
img = io.imread(input_filename)

# %%
## uncomment line below if using notebook and no access to your google drive
# !wget https://github.com/dani-lbnl/imagexd19/blob/master/dip/data/bead_pack.tif?raw=true
# Out:
# --2021-11-10 04:34:17--  https://github.com/dani-lbnl/imagexd19/blob/master/dip/data/bead_pack.tif?raw=true
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/dani-lbnl/imagexd19/raw/master/dip/data/bead_pack.tif [following]
# --2021-11-10 04:34:17--  https://github.com/dani-lbnl/imagexd19/raw/master/dip/data/bead_pack.tif
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dani-lbnl/imagexd19/master/dip/data/bead_pack.tif [following]
# --2021-11-10 04:34:17--  https://raw.githubusercontent.com/dani-lbnl/imagexd19/master/dip/data/bead_pack.tif
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8025493 (7.7M) [application/octet-stream]
# Saving to: ‘bead_pack.tif?raw=true’
#
# bead_pack.tif?raw=t 100%[===================>]   7.65M  --.-KB/s    in 0.09s
#
# 2021-11-10 04:34:18 (82.1 MB/s) - ‘bead_pack.tif?raw=true’ saved [8025493/8025493]

# %%
#!mv bead_pack.tif?raw=true bead_pack.tif

# %%
#!ls *.tif
# Out:
# bead_pack.tif

# %%
#img = io.imread('bead_pack.tif')

# %% [markdown]
# ## Basic image summary

# %%
print(f'* Shape: {img.shape}')
print(f'* Type:  {img.dtype}')
print(f'* Range: {img.min()} ,{img.max()}')
# Out:
# * Shape: (200, 200, 200)
# * Type:  uint8
# * Range: 29 ,239

# %% [markdown]
# ## Skim through

# %%
# Max projection is a fast way to pick on your stack content globally
x,_,_ = img.shape
IM_MAX = img[0,:,:]
for n in np.arange(1,x):
    IM_MAX = np.maximum(IM_MAX, img[n,:,:])
plt.imshow(IM_MAX)    
plt.colorbar()

# %%
#View each slice of original stack - notice downsample

from ipywidgets import interact,IntSlider

downsample = 2 #change to larger number if image shape > 1k 

def slicer(z):
    plt.imshow(img[z,::downsample,::downsample], cmap='gray')

interact(slicer, z=IntSlider(min=0, max=len(img), step=1, value=len(img)//2));
# Out:
# interactive(children=(IntSlider(value=100, description='z', max=200), Output()), _dom_classes=('widget-interac…

# %% [markdown]
# We will use the function slicer several times, so then let's create a way to quickly call it:

# %%
def slicing(b,lut='viridis'):
    def slicer(z):
        plt.imshow(b[z,:,:],cmap=lut, vmin=np.min(b), vmax=np.max(b)) #without vmin/vmax = dynamic :(
    interact(slicer, z=IntSlider(min=0,max=len(b)-1,step=1,value=len(b)//2));

# %% [markdown]
# ## Exercise: non-uniform background
# - calculate the mean projection of the stack
# - plot a downsampled mean projection with 1/3 total number of pixels

# %%
# %load solutions/ex01.py
x,y,z = img.shape
dtype = np.uint8 #fix: np.uint16
IM_MEAN = np.zeros((y,z), dtype=dtype)
for M in np.arange(0,x):
    IM_MEAN = IM_MEAN + img[M,:,:]
plt.imshow(IM_MEAN/x,cmap='gray')

# %%
# Understand why you need to change dtype 
from skimage import img_as_ubyte
v = IM_MEAN #v = img_as_ubyte(IM_MEAN)
print(f'* Range: {v.min()} ,{v.max()}')
plt.imshow(v)
# Out:
# * Range: 68 ,149

# %%
# %load solutions/ex02.py
plt.imshow(IM_MEAN[::3,::3])

# %% [markdown]
# ## Is the intensity distribution bimodal?

# %%
from skimage.util import img_as_ubyte
from skimage import data
from skimage.exposure import histogram


def seeHistSlice(img,nslice):
    noisy_image = img_as_ubyte(img[nslice,:,:])
    hist, hist_centers = histogram(noisy_image)
    fig, ax = plt.subplots(ncols=2, figsize=(10, 5))

    ax[0].imshow(noisy_image, cmap=plt.cm.gray, vmin=0, vmax=np.max(img))
    ax[0].set_title('Slice at the middle of the stack')
    ax[0].axis('off')

    ax[1].plot(hist_centers, hist, lw=2)
    ax[1].set_title('Histogram of grey values')
    ax[1].grid()

    plt.tight_layout()

# %%
#Change nslice
nslice = len(img)//2 
seeHistSlice(img,nslice)

# %% [markdown]
# Now let's put a scroll bar to visualize stack

# %%
def slicingHist(b):
    def slicer(z):
        seeHistSlice(b,z)
    interact(slicer, z=IntSlider(min=0,max=len(b)-1,step=1,value=len(b)//2));

# %%
slicingHist(img)
# Out:
# interactive(children=(IntSlider(value=100, description='z', max=199), Output()), _dom_classes=('widget-interac…

# %%
plt.imshow(img[:,:,1]>125,cmap='gray')

# %% [markdown]
# ## Adjust exposure
# - skimage.exposure.cumulative_distribution(image)
# - skimage.exposure.equalize(*args, **kwargs)
# - skimage.exposure.equalize_adapthist(image[, ...])
# - skimage.exposure.equalize_hist(image[, nbins])
# - skimage.exposure.histogram(image[, nbins])
# - skimage.exposure.rescale_intensity(image[, ...])

# %%
#Equalization for volume data, although you might be skiming through your data 
from skimage import exposure
a = exposure.equalize_hist(img)
slicing(a,'gray')
# Out:
# interactive(children=(IntSlider(value=100, description='z', max=199), Output()), _dom_classes=('widget-interac…

# %% [markdown]
# The Laplace operator or Laplacian is a differential operator given by the divergence of the gradient of a function on Euclidean space. In a Cartesian coordinate system, the Laplacian is given by the sum of second partial derivatives of the function with respect to each independent variable.

# %%
#Find the edges of an image using Laplacian
from skimage import filters as fi
img2 = fi.laplace(img)
slicing(img2,'gray')
# Out:
# interactive(children=(IntSlider(value=100, description='z', max=199), Output()), _dom_classes=('widget-interac…

# %% [markdown]
# ## Exercise: use other filters
# - Explore [[skimage.filters.rank]](https://scikit-image.org/docs/dev/api/skimage.filters.rank.html?highlight=rank#module-skimage.filters.rank) and apply to the 3D stack (suggestion: mean_bilateral, enhance_contrast)

# %%
# %load solutions/ex03.py
from skimage.filters.rank import mean_bilateral
from skimage.morphology import disk

bilat = np.empty_like(img)
for i, aslice in enumerate(img):
    bilat[i] = mean_bilateral(aslice.astype(np.uint8), disk(3), s0=15, s1=15)

slicing(img,'gray')
# Out:
# interactive(children=(IntSlider(value=100, description='z', max=199), Output()), _dom_classes=('widget-interac…

# %%
# %load solutions/ex04.py
from skimage.filters.rank import enhance_contrast

contr = np.empty_like(img)
for i, aslice in enumerate(img):
    contr[i]= enhance_contrast(aslice.astype(np.uint16),disk(3))
slicing(contr,'gray')
# Out:
# interactive(children=(IntSlider(value=100, description='z', max=199), Output()), _dom_classes=('widget-interac…

# %% [markdown]
# # Scipy ndimage
# - Multi-dimensional image processing/analysis: filters, interpolation, measurements
# - https://docs.scipy.org/doc/scipy/reference/ndimage.html

# %%
#Let's run a median filter on our stack
from scipy import ndimage as ndi
from skimage.morphology import ball

aball = ball(radius=2) #3D structure element
median = ndi.median_filter(img,footprint=aball)

# %%
slicing(median,'gray')
# Out:
# interactive(children=(IntSlider(value=100, description='z', max=199), Output()), _dom_classes=('widget-interac…

# %% [markdown]
# ## Exercise
# - Transform raw image into a morphologically dilated one, using grayscale dilation

# %%
# %load solutions/ex05.py
gdil = ndi.grey_dilation(img,footprint=aball)
slicing(gdil,'gray')
# Out:
# interactive(children=(IntSlider(value=100, description='z', max=199), Output()), _dom_classes=('widget-interac…

# %% [markdown]
# # Segmentation
# - categorize pixels into different 'classes' based on intensity values
# - next examples will use a single cut-off, but often +1 are more effective
# - mask an image

# %%
# checking the middle of the stack
import skimage.filters as fi
n=len(img)//2 #middle
print("See slice: " + str(n))
aslice = median[n,:,:]

fi.try_all_threshold(aslice, figsize=(4,8), verbose=False)
plt.savefig("thresholdAll.png", bbox_inches='tight')
# Out:
# See slice: 100

# %%
#warning: box-forced is removed in Matplotlib 3.1
import matplotlib
matplotlib.__version__
# Out:
# '3.2.2'

# %%
# After checking an adequate method, apply to the full tack and create BINARY version
t=fi.threshold_isodata(bilat)
binary = bilat>t

slicing(binary,'gray')
# Out:
# interactive(children=(IntSlider(value=100, description='z', max=199), Output()), _dom_classes=('widget-interac…

# %% [markdown]
# ## Masking and visualization
# - split image into background and foreground
# - use background area to hide portions of the image

# %%
def slicingMask(orig,binary):
    def slicer(z):
        plt.imshow(orig[z,:,:]*binary[z,:,:],cmap='gray',vmin=0, vmax=np.max(orig))
    interact(slicer, z=IntSlider(min=0,max=len(orig)-1,step=1,value=len(orig)//2));

# %%
# masking
slicingMask(img,binary)
# Out:
# interactive(children=(IntSlider(value=100, description='z', max=199), Output()), _dom_classes=('widget-interac…

# %% [markdown]
# ## Exercises:
# - Use function skimage.measure.label to create a labeled stack and output the number of connected components
#
# - Create a function that returns the largest connected component from a stack

# %%
#%load solutions/ex06.py
from skimage.measure import label
labeled = label(binary.astype('int'),connectivity=2)
print(np.max(labeled))

def slicer(z):
    plt.imshow(labeled[z,::downsample,::downsample], cmap='rainbow')

interact(slicer, z=IntSlider(min=0, max=len(labeled), step=1, value=68));
# Out:
# 27
# interactive(children=(IntSlider(value=68, description='z', max=200), Output()), _dom_classes=('widget-interact…

# %%
# %load solutions/ex07.py
from skimage.measure import label
labeled = label(binary.astype('int'),connectivity=2)
print(np.max(labeled))

def slicer(z):
    plt.imshow(labeled[z,::downsample,::downsample], cmap='rainbow',vmin=0,vmax=np.max(labeled))

interact(slicer, z=IntSlider(min=0, max=len(labeled), step=1, value=68));
# Out:
# 27
# interactive(children=(IntSlider(value=68, description='z', max=200), Output()), _dom_classes=('widget-interact…

# %%
# %load solutions/ex08.py
def getLargestCC(segments):
        '''Return a mask corresponding to the largest object'''
        labels = label(segments.astype('int'),connectivity=1)
        largestCC = labels == np.argmax(np.bincount(labels.flat, weights=segments.flat))
        return largestCC

a=getLargestCC(binary)

print('Volume largest obj: '+str(np.count_nonzero(a)))
print('Volume dense phase: '+str(np.count_nonzero(binary)))
# Out:
# Volume largest obj: 4994428
# Volume dense phase: 4994615

# %% [markdown]
# # Clean up binary representation

# %%
from skimage import morphology
aball = morphology.ball(radius=5) #aggressive

# %%
#3D Mathematical morphology
bin_e=morphology.binary_erosion(binary,selem=aball)
bin_o=morphology.binary_opening(binary,selem=aball)

# %%
#show two 2D images side by side for quick comparison
def imshowcmp(before,after,lut):
    f, ax = plt.subplots(1, 2, figsize=(20, 20))
    ax[0].imshow(before,cmap=lut)
    ax[1].imshow(after,cmap=lut)

# %%
imshowcmp(bin_e[n,:,:],bin_o[n,:,:],'gray')

# %%
binary=bin_e

# %%
labeled = label(binary.astype('int'),connectivity=2)
print(np.max(labeled))

slicing(labeled,'rainbow')
#do not fully trust what you see here
# Out:
# 299
# interactive(children=(IntSlider(value=100, description='z', max=199), Output()), _dom_classes=('widget-interac…

# %% [markdown]
# ## Remove small objects

# %%
cleaned = morphology.remove_small_objects(binary, min_size=5000, connectivity=1, in_place=False)

labeled = label(cleaned,connectivity=2)
print(np.max(labeled))
# Out:
# 204

# %% [markdown]
# ## Fill holes

# %%
from skimage.morphology import remove_small_holes
cleaned = remove_small_holes(cleaned, 100, connectivity=1, in_place=True)
labeled = label(cleaned,connectivity=2)
nobjects = np.max(labeled)
print('Estimated number of objects in the stack:'+str(nobjects))
# Out:
# Estimated number of objects in the stack:204

# %%
slicing(labeled,'rainbow')
# Out:
# interactive(children=(IntSlider(value=100, description='z', max=199), Output()), _dom_classes=('widget-interac…

# %%
# How to get a single object using labeled data?

loc = ndi.find_objects(labeled==50)[0]
bead = cleaned[loc]
bead.shape
np.sum(bead) #area
# Out:
# 8761

# %% [markdown]
# ## Inspecting connected components:
# - Create a graph where x=label number and y=volume of bead in pels
# - Estimate the number of beads

# %%
labeled = label(binary)
allBeads = ndi.find_objects(labeled)
nobjects = np.max(labeled)

accum = np.zeros(nobjects)
for i in np.arange(nobjects):
    loc = allBeads[i]
    bead = binary[loc]
    accum[i-1] = np.sum(bead)
plt.plot(accum)
plt.title('Median Volume on Raw Binary='+str(np.median(accum)))
plt.xlabel('Label of bead')
plt.ylabel('Volume of bead')
# Out:
# Text(0, 0.5, 'Volume of bead')

# %%
from skimage import segmentation
cleaned = segmentation.clear_border(cleaned)
labeled = label( cleaned )
allBeads = ndi.find_objects(labeled)
nobjects = np.max(labeled)
accum = np.zeros(nobjects)
for i in np.arange(nobjects):
    loc = allBeads[i]
    bead = binary[loc]
    accum[i-1] = np.sum(bead)
plt.plot(accum)
plt.title('Median Volume on Eroded stack='+str(np.median(accum)))
plt.grid()

# %%
print('Estimated number of objects in the stack: '+str(np.sum(cleaned) / 8816))
# Out:
# Estimated number of objects in the stack: 120.73332577132486

# %% [markdown]
# ## Exercises:
# - read from plant stack from git address below, segment the root and extract features
#  https://github.com/dani-lbnl/eyecopod/blob/main/plantStack.tif?raw=true

# %%
# Out:
# --2022-01-18 18:32:57--  https://github.com/dani-lbnl/eyecopod/blob/main/plantStack.tif?raw=true
# Resolving github.com (github.com)... 140.82.112.3
# Connecting to github.com (github.com)|140.82.112.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/dani-lbnl/eyecopod/raw/main/plantStack.tif [following]
# --2022-01-18 18:32:57--  https://github.com/dani-lbnl/eyecopod/raw/main/plantStack.tif
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/dani-lbnl/eyecopod/main/plantStack.tif [following]
# --2022-01-18 18:32:57--  https://raw.githubusercontent.com/dani-lbnl/eyecopod/main/plantStack.tif
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10207421 (9.7M) [application/octet-stream]
# Saving to: ‘plantStack.tif?raw=true’
#
# plantStack.tif?raw= 100%[===================>]   9.73M  --.-KB/s    in 0.06s
#
# 2022-01-18 18:32:58 (159 MB/s) - ‘plantStack.tif?raw=true’ saved [10207421/10207421]
#
# (1999, 1702, 3)

# %% [markdown]
# ## Checkpoints

# %%
from skimage.external import tifffile
path = "../data/cleaned.tiff"
tifffile.imsave(path,img_as_ubyte(cleaned))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-50-77034a042b84> in <module>()
#       1 from skimage.external import tifffile
#       2 path = "../data/cleaned.tiff"
# ----> 3 tifffile.imsave(path,img_as_ubyte(cleaned))
#
# /usr/local/lib/python3.7/dist-packages/skimage/external/tifffile/tifffile.py in imsave(file, data, **kwargs)
#     348         tifargs['bigtiff'] = True
#     349
# --> 350     with TiffWriter(file, **tifargs) as tif:
#     351         tif.save(data, **kwargs)
#     352
#
# /usr/local/lib/python3.7/dist-packages/skimage/external/tifffile/tifffile.py in __init__(self, file, append, bigtiff, byteorder, software, imagej)
#     488             self._fh.seek(0, 2)
#     489         else:
# --> 490             self._fh = FileHandle(file, mode='wb', size=0)
#     491             self._fh.write({'<': b'II', '>': b'MM'}[byteorder])
#     492             if bigtiff:
#
# /usr/local/lib/python3.7/dist-packages/skimage/external/tifffile/tifffile.py in __init__(self, file, mode, name, offset, size)
#    3517         self._close = True
#    3518         self.is_file = False
# -> 3519         self.open()
#    3520
#    3521     def open(self):
#
# /usr/local/lib/python3.7/dist-packages/skimage/external/tifffile/tifffile.py in open(self)
#    3528             self._file = os.path.realpath(self._file)
#    3529             self._dir, self._name = os.path.split(self._file)
# -> 3530             self._fh = open(self._file, self._mode)
#    3531             self._close = True
#    3532             if self._offset is None:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/data/cleaned.tiff'

# %%
path = "../data/labeled.tiff"
tifffile.imsave(path,img_as_ubyte(labeled))

# %%
path = "../data/bead.tiff"
tifffile.imsave(path,img_as_ubyte(bead))
